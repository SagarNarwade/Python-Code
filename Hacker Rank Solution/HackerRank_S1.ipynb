# %% [markdown]
# ![Screenshot 2021-07-17 at 13.08.16.png](data:image/png;base64,...)![Screenshot 2021-07-17 at 13.08.21.png](data:image/png;base64,...)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

k = int(input())
from itertools import combinations
  
def rSubset(a, r):
  
    # return list of all subsets of length r
    # to deal with duplicate subsets use 
    # set(list(combinations(arr, r)))
    return list(combinations(a, r))
  
# Driver Function
if __name__ == "__main__":
    a = input()
    a = a.replace(' ','')
    r = int(input())
    count = 0
    i = 'a'
    for j in range(0,len(rSubset(a,r))):
        if i in rSubset(a,r)[j]:
            count = count+1 
    print(count/len(rSubset(a,r)))
# Out:
# 4
# a a c d
# 2
# 0.8333333333333334
