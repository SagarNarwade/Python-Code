# %% [markdown]
# ![Screenshot 2021-07-17 at 15.52.32.png](data:image/png;base64,...)
# ![Screenshot 2021-07-17 at 15.52.36.png](data:image/png;base64,...)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
a = input()
a = a.split()
a = map(int, a)
a = list(a)
c = int(a[0])
b = int(a[1])
import random
e =[]
f = []
import re
k = ' '
for i in range(0,c):
    d = input()
    d = d.split()
    d = map(int, d)
    d = list(d)
    e.append(d)
    f.append(pow(int(random.choice(e[i])),2))
print(sum(f)%b)

#print(sum(5^2,9^2,10^2))
# Out:
# 3 1000
# 2 5 4
# 3 7 8 9
# 5 5 7 8 9 10
# 131
